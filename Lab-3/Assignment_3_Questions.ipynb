# %% [markdown]
# <table>
# <tr>
# <td width=15%><img src="https://www.nitrkl.ac.in/assets/images/logo.png"></img></td>
# <td><center><h1>National Institute of Technology
# Rourkela, Odisha, India, 769008</h1><h2>Department of Computer Science Engineering</h2></center></td>
# </tr>
# <tr><td colspan=2><center><h3>Laborotary-4</h3></br>
#             <b>(Data Science Laborotary)</b></center></td></tr>
# </table>

# %% [markdown]
# ##Linear Regression

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Read the salary dataset

# %%
# your answer here
dataset = pd.read_csv('Salary_Data.csv')

# %% [markdown]
# Show the first 10 rows of the dataset

# %%
# your answer here
dataset.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %% [markdown]
# Show the dimensions (No. of rows and coulmns) of the dataset

# %%
# your answer here
dataset.shape
# Out:
# (30, 2)

# %% [markdown]
# Print all the column names of the dataset

# %%
# your answer here
dataset.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %% [markdown]
# Print general information of the dataset like column, and datatype.

# %%
# your answer here
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %% [markdown]
# Extract independent and dependent features and store it in two different variables.

# %%
# your answer here
yearsExperience = dataset['YearsExperience'] 
salary = dataset['Salary']

# %% [markdown]
# Split the dataset into train and test set

# %%
from sklearn.model_selection import train_test_split

# %%
# your answer here
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size= 0.2, random_state= 0)
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (24, 1) (6, 1) (24,) (6,)

# %% [markdown]
# Training the Simple Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression

# %%
# your answer here
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Predict the Test set results

# %%
# your answer here
Y_pred = regressor.predict(X_test)

# %% [markdown]
# Visualize the linear regression on training data using scatterplot.

# %%
# your answer here
plt.scatter(X_train, Y_train, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Visualize the linear regression on test data using scatterplot.

# %%
# your answer here
plt.scatter(X_test, Y_test, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')  
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Finding R^2 score

# %%
from sklearn.metrics import r2_score

# %%
# your answer here
r2_score(Y_test, Y_pred)
# Out:
# 0.988169515729126

# %% [markdown]
# Ridge Regression

# %%
# Ridge Regression
from sklearn.linear_model import Ridge
model = Ridge(alpha=0.5)
model.fit(X_train, Y_train)
predictions = model.predict(X_test)
print(r2_score(Y_test,predictions))
# Out:
# 0.987891303817413

# %%
plt.scatter(X_train, Y_train, color='red')
plt.plot(X_train, model.predict(X_train), color='blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Huber Regression

# %%
from sklearn.linear_model import HuberRegressor
model = HuberRegressor()
model.fit(X_train, Y_train)
predictions = model.predict(X_test)
print(r2_score(Y_test,predictions))
# Out:
# 0.9870632883295445

# %%
plt.scatter(X_train, Y_train, color='red')
plt.plot(X_train, model.predict(X_train), color='blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNet
model = ElasticNet()
model.fit(X_train, Y_train)
predictions = model.predict(X_test)
print(r2_score(Y_test,predictions))
# Out:
# 0.9772686017240042

# %%
plt.scatter(X_train, Y_train, color='red')
plt.plot(X_train, model.predict(X_train), color='blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Lasso Regression

# %%
from sklearn.linear_model import Lasso
model = Lasso()
model.fit(X_train, Y_train)
predictions = model.predict(X_test)
print(r2_score(Y_test,predictions))
# Out:
# 0.988168127365881

# %%
plt.scatter(X_train, Y_train, color='red')
plt.plot(X_train, model.predict(X_train), color='blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ##Logistic Regression

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# Read the heart failure dataset

# %%
# your answer here
heart_data = pd.read_csv('heart.csv')

# %% [markdown]
# Display the first five rows

# %%
# your answer here
heart_data.head(5)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# Check for missing values

# %%
# your answer here
heart_data.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# Describe numerical features

# %%
# your answer here
heart_data.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %% [markdown]
# Visualize the distribution of key features (Age, Cholesterol, MaxHR) using histograms.

# %%
# your answer here
heart_data['Age'].hist(bins=20)
plt.title('Age Distribution')
plt.show()


heart_data['Cholesterol'].hist(bins=20)
plt.title('Cholesterol Distribution')
plt.show()

heart_data['MaxHR'].hist(bins=20)
plt.title('MaxHR Distribution')
plt.show()

# %% [markdown]
# List all categorical_features

# %%
# your answer here
categorical_features = heart_data.select_dtypes(include=['object']).columns
print(categorical_features)
# Out:
# Index(['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope'], dtype='object')

# %% [markdown]
# Convert categorical variables into numerical format using label encoding.

# %%
# your answer here
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
for column in categorical_features:
    heart_data[column] = label.fit_transform(heart_data[column])
    print(heart_data[categorical_features].head())
# Out:
#    Sex ChestPainType RestingECG ExerciseAngina ST_Slope
# 0    1           ATA     Normal              N       Up
# 1    0           NAP     Normal              N     Flat
# 2    1           ATA         ST              N       Up
# 3    0           ASY     Normal              Y     Flat
# 4    1           NAP     Normal              N       Up
#    Sex  ChestPainType RestingECG ExerciseAngina ST_Slope
# 0    1              1     Normal              N       Up
# 1    0              2     Normal              N     Flat
# 2    1              1         ST              N       Up
# 3    0              0     Normal              Y     Flat
# 4    1              2     Normal              N       Up
#    Sex  ChestPainType  RestingECG ExerciseAngina ST_Slope
# 0    1              1           1              N       Up
# 1    0              2           1              N     Flat
# 2    1              1           2              N       Up
# 3    0              0           1              Y     Flat
# 4    1              2           1              N       Up
#    Sex  ChestPainType  RestingECG  ExerciseAngina ST_Slope
# 0    1              1           1               0       Up
# 1    0              2           1               0     Flat
# 2    1              1           2               0       Up
# 3    0              0           1               1     Flat
# 4    1              2           1               0       Up
#    Sex  ChestPainType  RestingECG  ExerciseAngina  ST_Slope
# 0    1              1           1               0         2
# 1    0              2           1               0         1
# 2    1              1           2               0         2
# 3    0              0           1               1         1
# 4    1              2           1               0         2

# %% [markdown]
# Analyze the correlation between features using a heatmap.

# %%
# your answer here
plt.figure(figsize=(10, 8))
sns.heatmap(heart_data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Split the dataset into training and testing sets (80-20 split).

# %%
# your answer here
dataset = heart_data.copy()
X_train, X_test, y_train, y_test = train_test_split(dataset.drop('HeartDisease', axis=1), dataset['HeartDisease'], test_size=0.2, random_state=0)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (734, 11) (184, 11) (734,) (184,)

# %% [markdown]
# Perform hyperparameter tuning on logistic regression using GridSearchCV to find the best parameters

# %%
# your answer here
parameters = {'C': [0.1, 1, 10, 100], 'penalty': ['l1', 'l2'], "solver": ['liblinear']}
model = LogisticRegression(max_iter=1000)
grid_search = GridSearchCV(model, parameters)
grid_search.fit(X_train, y_train)
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.856937843630603

# %% [markdown]
# Train the logistic regression model using the best parameters obtained from GridSearchCV and evaluate its performance on the test set using accuracy, confusion matrix, and classification report.

# %%
# your answer here
model = LogisticRegression(C=grid_search.best_params_['C'], penalty=grid_search.best_params_['penalty'], solver=grid_search.best_params_['solver'], max_iter=1000)
model.fit(X_train, y_train)
predictions = model.predict(X_test)
print(accuracy_score(y_test, predictions))
# Out:
# 0.8369565217391305

# %%
from sklearn.metrics import roc_curve, auc

# %%
# your answer here
fpr, tpr, thresholds = roc_curve(y_test, predictions)
roc_auc = auc(fpr, tpr)
print(roc_auc)
plt.plot(fpr, tpr, color='black', label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0,1], [0,1], color='orange', linestyle='-')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# 0.8270421167617429
# [[59 18]
#  [12 95]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80        77
#            1       0.84      0.89      0.86       107
#
#     accuracy                           0.84       184
#    macro avg       0.84      0.83      0.83       184
# weighted avg       0.84      0.84      0.84       184

# %% [markdown]
# LINEAR REGRESSION TUNING

# %% [markdown]
# Ridge Regression

# %%
parameters = {'alpha': [0.001, 0.01, 0.1, 1], 'fit_intercept': [True, False], 'max_iter': [1000]}
model = Ridge()
grid_search = GridSearchCV(model, parameters)
grid_search.fit(X_train, y_train)
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'alpha': 1, 'fit_intercept': True, 'max_iter': 1000}
# 0.5053722374674403

# %%
model = Ridge(alpha=grid_search.best_params_['alpha'], fit_intercept=grid_search.best_params_['fit_intercept'], max_iter=grid_search.best_params_['max_iter'])
X_train, X_test, Y_train, Y_test = train_test_split(dataset['YearsExperience'], dataset['Salary'], test_size=0.2, random_state=0)
model.fit(X_train, y_train)
predictions = model.predict(X_test)
print("Grid: ", r2_score(y_test, predictions))

plt.scatter(X_train, model.predict(X_train), color='red')
plt.title('Grid VS Default')
plt.xlabel('Actual')
plt.ylabel('Predicted')

model = Ridge()
model.fit(X_train, y_train)
predictions = model.predict(X_test)
print("Default: ", r2_score(y_test, predictions))

plt.scatter(X_train, model.predict(X_train), color='blue')
plt.legend(['Grid', 'Default'])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YearsExperience'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[123], line 2
#       1 model = Ridge(alpha=grid_search.best_params_['alpha'], fit_intercept=grid_search.best_params_['fit_intercept'], max_iter=grid_search.best_params_['max_iter'])
# ----> 2 X_train, X_test, Y_train, Y_test = train_test_split(dataset['YearsExperience'], dataset['Salary'], test_size=0.2, random_state=0)
#       3 model.fit(X_train, y_train)
#       4 predictions = model.predict(X_test)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'YearsExperience'
